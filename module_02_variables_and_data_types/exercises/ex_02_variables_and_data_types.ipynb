# %% [markdown]
# ## Exercise: Create Variables
# Create a variable for each type: int, float, str, bool, NoneType
#
# Print each variable AND its type, on the same line.
#
# Expected format:  42 <class 'int'>

# %%
print("\n[ Exercise 1 ]")
# your answers here

# %% [markdown]
# ## Exercise: Personal Profile
# Create variables for: your name, age, height, whether you are a student, and your favorite color.
#
# Print a summary using those variables.

# %%
print("\n[ Exercise 2 ]")
# your answer here

# %% [markdown]
# ## Exercise: Tuple Unpacking
# Assign the values 10, 20, 30 to variables x, y, z using a single line of code. Then print them.

# %%
print("\n[ Exercise 3 ]")
# your answer here
# Out:
# [ Exercise 3 ]

# %% [markdown]
# ## Exercise: Variable Swap
# Given a and b, swap their values without using a third variable.
#
# Print before and after.

# %%
print("\n[ Exercise 4 ]")
a = 100
b = 200
print(f"Before: a={a}, b={b}")
# your answer here
print(f"After:  a={a}, b={b}")

# %% [markdown]
# ## Exercise: Type Detective
# Given the variables below, print a sentence describing each one.
#
# Format: "mystery_x is a *type* with value *value*"

# %%
print("\n[ Exercise 5 ]")
mystery_1 = 3.14
mystery_2 = "Python"
mystery_3 = 99
mystery_4 = False
mystery_5 = None

# your answer here

# %% [markdown]
# ## Exercise: Dynamic Typing
# Create a variable called "shape_shifter", assign it an int, print it with its type.
#
# Then reassign it to a str, print again.
#
# Then reassign to a bool, print again.

# %%
shape_shifter =
# assign and print

# %% [markdown]
# ## Exercise: Temperature Converter
#
# Store a Celsius temperature in a variable, convert it to Fahrenheit, and print both (round to 1 decimal place)

# %%
print("\n[ Exercise 6 ]")
# Formula: F = (C * 9/5) + 32
# Expected Output: 100.0 C = 212.0 F
# Hint: to round, use round(value, number), where number is the decimal place and value is the thing you are rounding

# your answer here

# %% [markdown]
# ## Exercise: Fix the Bug
#
# The code below crashes. Figure out why, fix it, and print the correct result

# %%
print("\n[ Exercise 7 ]")
user_age = "25"
years_until_30 = 30 - user_age
print(f"Years until 30: {years_until_30}")

# Hint: Check the data types, you can't do arithmetic with different data types
# your answer here
